# %%
from pathlib import Path

import numpy as np
import pandas as pd

from parliament.main import ResultsContainer


#experiment_name = 'full_run_01062021'
experiment_name = 'cvc_all_with_efforting'
#experiment_name = 'dcadebugging'
#experiment_name = 'howe_potential_fix_subtract_peep'
container = ResultsContainer.load_from_experiment_name(experiment_name)
container.wmd_n = 20
container.dpi = 150
# more boot strap resamples will give you a tighter confidence interval.
container.boot_resamples = 50
container.analyze_results()
try:
    container.full_analysis_done
except Exception:
    container.analyze_results()

if not container.full_analysis_done:
    container.analyze_results()
# Out:
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
container.extract_descriptive_statistics()
# Out:
# <h2>Data Descriptive Statistics</h2>
# <table>
#     <thead>
#         <tr>
#             <th>stat</th>
#             <th>val</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>n patients</td>
#             <td>8</td>
#         </tr>
#         <tr>
#             <td>% Female</td>
#             <td>TODO</td>
#         </tr>
#         <tr>
#             <td>Age (IQR)</td>
#             <td>TODO</td>
#         </tr>
#         <tr>
#             <td>median RASS (IQR)</td>
#             <td>TODO</td>
#         </tr>
#         <tr>
#             <td>% paralyzed</td>
#             <td>TODO</td>
#         </tr>
#         <tr>
#             <td>n vc patients</td>
#             <td>8</td>
#         </tr>
#         <tr>
#             <td>n pc patients</td>
#             <td>4</td>
#         </tr>
#         <tr>
#             <td>n prvc patients</td>
#             <td>5</td>
#         </tr>
#         <tr>
#             <td>total breaths</td>
# ...

# %%
masks = container.get_masks()
out = container.compare_masks(masks['no_async'], masks['async_and_efforting'], False)
# Out:
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:164: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# ...

# %%
masks = container.get_masks()
container.visualize_patient('cvc_20171121', ['iimipr', 'iipr', 'iipredator', 'predator', 'pt_insp_lstsq', 'al_rawas'], extra_mask=masks['bsa'])
# Out:
# /home/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:164: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 164 of the file /home/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(table.get_html_string())
# <h2>Patient cvc_20180705. Custom plot</h2>
# <table>
#  <thead>
#   <tr>
#    <th>
#     Algorithm
#    </th>
#    <th>
#     Shorthand Name
#    </th>
#    <th>
#     MAD (Median Absolute Deviation)
#    </th>
#    <th>
#     Standard Deviation (std)
#    </th>
#   </tr>
#  </thead>
#  <tbody>
# ...

# %%
container.plot_per_patient_results(use_wmd=False, show_boxplots=False)
# Out:
# /home/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:164: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 164 of the file /home/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(table.get_html_string())
# <h2>Patient by patient results. No filters</h2>
# <table>
#  <thead>
#   <tr>
#    <th>
#     Algorithm
#    </th>
#    <th>
#     Shorthand Name
#    </th>
#    <th>
#     MAD (Median Absolute Deviation)
#    </th>
#    <th>
#     Standard Deviation (std)
#    </th>
#   </tr>
#  </thead>
# ...

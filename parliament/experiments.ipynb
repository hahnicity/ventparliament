# %%
from pathlib import Path

import pandas as pd

from parliament.main import ResultsContainer


experiment_name = 'full_run_with_tor_vm'
container = ResultsContainer.load_from_experiment_name(experiment_name)
container.analyze_results()
# Out:
# /Users/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/greg/anaconda3/envs/parliament/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
container.plot_per_patient_results()
# Out:
# /Users/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:178: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:188: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/greg/workspace/python/single_chamber_algo_benchmarks/parliament/main.py:195: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
